# %% [markdown]
# Python Strings : Strings are sentences or words that are enclosed in either single quotes (' '), double quotes (" "), or triple quotes (''' ''' or """ """). They are used to represent text in Python.
# # Example of a string in Python
# greeting = "Hello, World!"

# %%
print("Hello")
a = 100
b = 200
c = a + b
print(a,b,c)
# Out:
# Hello
# 100 200 300
